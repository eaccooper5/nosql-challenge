# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
hygiene_query = {'scores.Hygiene': 20}
hygiene_results = list(establishments.find(hygiene_query))
# Use count_documents to display the number of documents in the result
print(establishments.count_documents(hygiene_query))
# Display the first document in the results using pprint
pprint(establishments.find_one(hygiene_query))
# Out:
# 41
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65ba9a8f21d413d86bf5d25f'),
#  'geocode': {'latitude': 50.769705, 'longitude': 0.27694},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/110681',
# ...

# %%
# Convert the result to a Pandas DataFrame
hygiene_df = pd.DataFrame(hygiene_results)
# Display the number of rows in the DataFrame
len(hygiene_df)
# Display the first 10 rows of the DataFrame
hygiene_df.head(10)
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  65ba9a8f21d413d86bf5d25f   110681                  0
# 1  65ba9a8f21d413d86bf5d5e0   612039                  0
# 2  65ba9a8f21d413d86bf5d8ea   730933                  0
# 3  65ba9a8f21d413d86bf5dad9   172735                  0
# 4  65ba9a8f21d413d86bf5dae4   172953                  0
# 5  65ba9a8f21d413d86bf5e487   512854                  0
# 6  65ba9a8f21d413d86bf5e6bc  1537089                  0
# 7  65ba9a9021d413d86bf5fbd4   155648                  0
# 8  65ba9a9021d413d86bf60015  1012883                  0
# 9  65ba9a9021d413d86bf60829   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# ...

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
highRating_query = {'LocalAuthorityName': 'London'}
highRating_fields = {'RatingValue': {'$gte': 4}}


print(highRating_fields)
#highRating_results = establishments.find(highRating_query, highRating_fields)

# Use count_documents to display the number of documents in the result
#print(establishments.count_documents(highRating_results))
# Display the first document in the results using pprint
#pprint(establishments.find_one(highRating_results))
# Out:
# {'RatingValue': {'$gte': 4}}

# %%
# Convert the result to a Pandas DataFrame
London_results = pd.DataFrame(highRating_results)
# Display the number of rows in the DataFrame
len(London_results)
# Display the first 10 rows of the DataFrame
London_results.head(10)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[24], line 2
#       1 # Convert the result to a Pandas DataFrame
# ----> 2 London_results = pd.DataFrame(highRating_results)
#       3 # Display the number of rows in the DataFrame
#       4 len(London_results)
#
# File c:\Users\schad\anaconda3\envs\dev\lib\site-packages\pandas\core\frame.py:774, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772         data = np.asarray(data)
#     773     else:
# --> 774         data = list(data)
#     775 if len(data) > 0:
#     776     if is_dataclass(data[0]):
#
# File c:\Users\schad\anaconda3\envs\dev\lib\site-packages\pymongo\cursor.py:1264, in Cursor.next(self)
#    1262 if self.__empty:
#    1263     raise StopIteration
# -> 1264 if len(self.__data) or self._refresh():
#    1265     return self.__data.popleft()
#    1266 else:
#
# ...

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude =  {'geocode': {'longitude': '0.08384000'}}
longitude = {'geocode': {'latitude': '51.49014200'}}

query = {'RatingValue': 5}
sort =  [{'scores': {'Hygiene': 1}}]

top_5_search = list(establishments.find(query, degree_search).sort(sort).limit(5))

# Print the results
pprint(top_5_search)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 12
#       9 query = {'RatingValue': 5}
#      10 sort =  [{'scores': {'Hygiene': 1}}]
# ---> 12 top_5_search = list(establishments.find(query, degree_search).sort(sort).limit(5))
#      14 # Print the results
#      15 pprint(top_5_search)
#
# File c:\Users\schad\anaconda3\envs\dev\lib\site-packages\pymongo\collection.py:1697, in Collection.find(self, *args, **kwargs)
#    1510 def find(self, *args: Any, **kwargs: Any) -> Cursor[_DocumentType]:
#    1511     """Query the database.
#    1512
#    1513     The `filter` argument is a query document that all results
#    (...)
#    1695     .. seealso:: The MongoDB documentation on `find <https://dochub.mongodb.org/core/find>`_.
#    1696     """
# -> 1697     return Cursor(self, *args, **kwargs)
#
# ...

# %%
# Convert result to Pandas DataFrame

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest

match_query = {'$match': {'scores.Hygiene': 0}}

group_query = {'$group': {'LocalAuthorityBusinessID': '', 'count': {'$sum': 1}}}

sort_values = {'$sort': {'count': -1}}

pipeline = [match_query, group_query, sort_values]

lowHygiene_score_results = list(establishments.aggregate(pipeline))

# Print the number of documents in the result

print(len(lowHygiene_score_results))

# Print the first 10 results
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[32], line 14
#      10 sort_values = {'$sort': {'count': -1}}
#      12 pipeline = [match_query, group_query, sort_values]
# ---> 14 lowHygiene_score_results = list(establishments.aggregate(pipeline))
#      16 # Print the number of documents in the result
#      18 print(len(lowHygiene_score_results))
#
# File c:\Users\schad\anaconda3\envs\dev\lib\site-packages\pymongo\collection.py:2720, in Collection.aggregate(self, pipeline, session, let, comment, **kwargs)
#    2642 """Perform an aggregation using the aggregation framework on this
#    2643 collection.
#    2644
#    (...)
#    2717     https://mongodb.com/docs/manual/reference/command/aggregate
#    2718 """
#    2719 with self.__database.client._tmp_session(session, close=False) as s:
# -> 2720     return self._aggregate(
# ...

# %%
# Convert the result to a Pandas DataFrame

# Display the number of rows in the DataFrame

# Display the first 10 rows of the DataFrame
